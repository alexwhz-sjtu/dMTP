# %% [markdown]
# 输入：数据集，提取prompt
# 数据保存：一个prompt生成的token以及对应的hidden states，最大长度为max_length，保存为一个文件

# %%
CUDA_VISIBLE_DEVICES=4 python /share/wanghanzhen/MTP/d-Spec/train_eaglestyle/data_collection/data_collection.py \
    --base_model_path /share/public/public_models/Qwen2.5-7B-Instruct \
    --input_data_path /share/wanghanzhen/MTP/d-Spec/dataset/LongWriter/evaluation/longbench_write_en.jsonl \
    --output_dir /share/wanghanzhen/MTP/d-Spec/train_eaglestyle/data_collection/training_data_demo \
    --max_samples 100 \
    --max_new_tokens 128
