# %%
python -m evaluation.eval --depth 10 --temperature 0.0 --bench-name spec-bench --max-new-tokens 128

# %%
# 启用 MTP 模式
python run.py --mtp-mode

# 使用 naive 模式（默认）
python run.py

# 自定义 prompt 和参数
python run.py --mtp-mode --prompt "Explain quantum computing." --max-length 2048 --temperature 0.7

# %%
python train_mtp_head.py \
    --model_name_or_path /share/wanghanzhen/MTP/d-Spec/mtpmodel \
    --train_data_dir /share/wanghanzhen/MTP/d-Spec/training_data \
    --output_dir ./mtp_checkpoints \
    --block_length 4 \
    --per_device_train_batch_size 64 \
    --num_train_epochs 10 \
    --learning_rate 5e-5 \
    --warmup_steps 500 \
    --logging_steps 1000 \
    --save_steps 10000 \
    --dataloader_num_workers 8 \
    --scheduler_type linear
